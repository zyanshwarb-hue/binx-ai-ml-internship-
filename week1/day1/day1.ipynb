# %% [markdown]
# # 🛠️ Day 1 — Environment Setup
#
# **BinX Tech AI/ML Internship Program**
#
# ---
#
# ## 🎯 Objectives
# - Set up a clean Python virtual environment for the internship
# - Verify that Python, NumPy, Pandas, and Matplotlib are installed correctly
# - Freeze the environment into a `requirements.txt` file for reproducibility
# - Initialize Git and push the first notebook to GitHub

# %% [markdown]
# ---
#
#
# ## 1️⃣ First Notebook Test
#
# A simple print statement to confirm the Jupyter Notebook environment runs correctly.

# %%
print("Hello my first notebook")
# Out:
# Hello, my first notebook!

# %% [markdown]
# ---
#
#
#
# ## 2️⃣ Verify Library Installation
#
# Importing NumPy, Pandas, and Matplotlib and printing their versions to confirm all core libraries are installed correctly.

# %%
import numpy
import pandas
import matplotlib
print("NumPy version:", numpy.__version__)
print("Pandas version:", pandas.__version__)
print("Matplotlib version:", matplotlib.__version__)
# Out:
# NumPy version: 2.5.1
# Pandas version: 3.0.3
# Matplotlib version: 3.11.1

# %% [markdown]
# ---
#
#
# ## 3️⃣ Freeze Environment
#
# Recording the exact installed package versions into `requirements.txt` for reproducibility.

# %%
# !pip freeze > requirements.txt

# %% [markdown]
# ## 4️⃣ Environment & Git Setup (done via terminal)
#
# | Step | Task | Command |
# |------|------|---------|
# | 1 | Created and activated a virtual environment | `python -m venv .venv` |
# | 2 | Installed required libraries | `pip install numpy pandas matplotlib jupyter` |
# | 3 | Initialized a Git repository | `git init` |
# | 4 | Committed the notebook and requirements file | `git add . && git commit -m "Initial setup"` |
