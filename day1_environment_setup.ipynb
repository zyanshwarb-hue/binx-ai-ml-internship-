# %% [markdown]
# # Week 1 - Day 1: Environment Setup
#
# This notebook verifies that Python, NumPy, Pandas, and Matplotlib
# are installed correctly for the internship program.

# %% [markdown]
# ### Step 1: First Notebook Test
# A simple print statement to confirm the Jupyter Notebook environment runs correctly.

# %%
print("Hello my first notebook")
# Out:
# Hello, my first notebook!

# %% [markdown]
# ### Step 2: Verify Library Installation
# Importing NumPy, Pandas, and Matplotlib and printing their versions to confirm all core libraries are installed correctly.

# %%
import numpy
import pandas
import matplotlib
print("NumPy version:", numpy.__version__)
print("Pandas version:", pandas.__version__)
print("Matplotlib version:", matplotlib.__version__)
# Out:
# NumPy version: 2.5.1
# Pandas version: 3.0.3
# Matplotlib version: 3.11.1

# %% [markdown]
# ### Step 3: Freeze Environment
# Recording the exact installed package versions into `requirements.txt` for reproducibility.

# %%
# !pip freeze > requirements.txt

# %% [markdown]
# ### Environment & Git Setup (done via terminal)
# - Created and activated a virtual environment: `python -m venv .venv`
# - Installed required libraries: `pip install numpy pandas matplotlib jupyter`
# - Initialized a Git repository and committed this notebook with `requirements.txt`.
